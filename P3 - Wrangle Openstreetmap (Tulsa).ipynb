# %%
import xml.etree.cElementTree as ET
import pprint
from collections import defaultdict
import re

rawOSMfile = "Tulsa map.osm"

street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)
number_in_string = re.compile('\d+')
street_type_in_string = re.compile(' Avenue| Ave| Lane| Ln| Road| Rd| Boulevard| Blvd| Drive| Dr| Street| St| Highway| Hwy', re.IGNORECASE)


expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons"]

#function to audit street types
def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)

def is_street_name(elem):
    if elem.attrib['k'] == "addr:street":
        return True
    elif elem.attrib['k'] == "name":
        #check if string contains a number and a street type
        if re.search(street_type_in_string, elem.attrib['v']):
            if re.search(number_in_string, elem.attrib['v']):
                return True
    else:
        return False
           


def audit(osmfile):
    osm_file = open(rawOSMfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    osm_file.close()
    return street_types

#run the audit street type function to see results of the Tulsa openstreetmap dataset
st_types = audit(rawOSMfile)
pprint.pprint(dict(st_types))
# Out:
# {'1': set(['Catoosa Fire Station #1',
#            'Denver Avenue Station Bay 1',
#            'Memorial Midtown Station Bay 1',
#            'Rolling Hills Fire Protection District Station #1']),
#  '10': set(['Denver Avenue Station Bay 10',
#             'Memorial Midtown Station Bay 10']),
#  '1045': set(['1045']),
#  '11': set(['Denver Avenue Station Bay 11',
#             'Memorial Midtown Station Bay 11']),
#  '12': set(['Memorial Midtown Station Bay 12']),
#  '15': set(['Tulsa Fire Station Number 15']),
#  '167': set(['Oklahoma State Highway 167']),
#  '2': set(['Catoosa Fire Station #2',
#            'Denver Avenue Station Bay 2',
#            'Memorial Midtown Station Bay 2',
#            'Rolling Hills Fire Protection District Fire Station #2']),
#  '2502': set(['2502']),
#  '3': set(['Denver Avenue Station Bay 3', 'Memorial Midtown Station Bay 3']),
#  '4': set(['Denver Avenue Station Bay 4', 'Memorial Midtown Station Bay 4']),
#  '5': set(['Broken Arrow Fire Station #5',
#            'Denver Avenue Station Bay 5',
#            'Memorial Midtown Station Bay 5']),
#  '503': set(['503']),
#  '51': set(['Old Highway 51']),
#  '6': set(['Broken Arrow Fire Department Station #6',
#            'Denver Avenue Station Bay 6',
#            'Memorial Midtown Station Bay 6']),
#  '66': set(['North Old Highway 66']),
#  '7': set(['Denver Avenue Station Bay 7', 'Memorial Midtown Station Bay 7']),
#  '74132-3004': set(['4616 W 84th St, Tulsa, OK  74132-3004']),
#  '8': set(['Denver Avenue Station Bay 8', 'Memorial Midtown Station Bay 8']),
#  '8828': set(['8828']),
#  '9': set(['Denver Avenue Station Bay 9', 'Memorial Midtown Station Bay 9']),
#  'A': set(['South Peoria Place, Apt A']),
#  'AVenue': set(['South 259th East AVenue']),
#  'Archer': set(['Archer']),
#  'Ave': set(['S Harvard Ave', 'S Peoria Ave']),
#  'Avenu': set(['South Olympia Avenu']),
#  'Brook': set(['Pebble Brook']),
#  'Center': set(['Civic Center', 'Williams Center']),
#  'Cherokee': set(['S Cherokee', 'South Cherokee']),
#  'Church': set(['49th Street Hill Church']),
#  'Circle': set(['North Hemlock Circle']),
#  'Dr.': set(['South Memorial Dr.']),
#  'East': set(['288th Avenue East',
#               'North 10th Street East',
#               'North 77th Avenue East',
#               'South 101st Avenue East',
#               'South 106th Avenue East',
#               'South 107th Avenue East',
#               'South 108th Avenue East',
#               'South 110th Avenue East',
#               'South 118th Avenue East',
#               'South 130th Avenue East',
#               'South 139th Avenue East',
#               'South 167th Avenue East',
#               'South 173rd Avenue East',
#               'South 261st Avenue East',
#               'South 66th Avenue East',
#               'South 67th Avenue East',
#               'South 68th Avenue East',
#               'South 70th Avenue East',
#               'South 71st Avenue East',
#               'South 72nd Avenue East',
#               'South 74th Avenue East',
#               'South 77th Avenue East',
#               'South 79th Avenue East',
#               'South 83rd Avenue East',
#               'South 87th Avenue East',
#               'South 90th Avenue East',
#               'South 91st Avenue East',
#               'South 92nd Avenue East',
#               'South 94th Avenue East',
#               'South 95th Avenue East',
#               'South 99th Avenue East',
#               'South Sheridan Road East',
#               'South Toledo Avenue East']),
#  'Expressway': set(['Broken Arrow Expressway']),
#  'Florence': set(['West Florence']),
#  'Island': set(['71st Street Island']),
#  'King': set(['King']),
#  'Main': set(['East Main']),
#  'North': set(['34th Street North',
#                '38th Street North',
#                '41st Street North',
#                '43rd Street North',
#                '50th Street North',
#                '53 Road Street North',
#                '55th Street North',
#                '58th Street North',
#                'East 106th Street North',
#                'East 135th Street North',
#                'East 136th Street North',
#                'East 146th Street North',
#                'East 156th Street North',
#                'East 158th Street North',
#                'East 166th Street North',
#                'East 168th Street North',
#                'East 173rd Street North',
#                'East 176th Street North',
#                'East 27th Street North',
#                'East 28th Street North',
#                'East 29th Street North',
#                'East 30th Street North',
#                'East 31st Street North',
#                'East 32nd Street North',
#                'East 33rd Street North',
#                'East 34th Street North',
#                'East 35th Street North',
#                'East 36th Street North',
#                'East 37th Street North',
#                'East 38th Street North',
#                'East 39th Street North',
#                'East 41st Street North',
#                'East 42nd Street North',
#                'East 43rd Street North',
#                'East 44th Street North',
#                'East 45th Street North',
#                'East 46th Street North',
#                'East 47th Street North',
#                'East 48th Street North',
#                'East 49th Street North',
#                'East 50th Street North',
#                'East 51st Street North',
#                'East 52nd Street North',
#                'East 53rd Street North',
#                'East 54th Street North',
#                'East 55th Street North',
#                'East 56th Street North',
#                'East 57th Street North',
#                'East 58th Street North',
#                'East 59th Street North',
#                'East 62nd Street North',
#                'East 76th Street North',
#                'East 86th Street North',
#                'East 98th Street North',
#                'East 99th Street North',
#                'East Pine Street North',
#                'West 27th Street North',
#                'West 28th Street North',
#                'West 34th Street North',
#                'West 36th Street North',
#                'West 38th Street North',
#                'West 41st Street North',
#                'West 46th Street North',
#                'West 47th Street North',
#                'West 48th Street North',
#                'West 49th Street North',
#                'West 50th Street North',
#                'West 53rd Street North',
#                'West 56th Street North',
#                'West 57th Street North',
#                'West 58th Street North']),
#  'Plaza': set(['41st Street Plaza']),
#  'Promenade': set(['Tulsa Promenade']),
#  'Rd': set(['E BA Frontage Rd', 'S. Sheridan Rd']),
#  'River': set(['116th Street Arkansas River']),
#  'S': set(['S Cheyenne Ave&W 3Rd St S']),
#  'Sheridan': set(['Sheridan']),
#  'South': set(['101st Street South',
#                '104 Street South',
#                '104th Street South',
#                '105 Street South',
#                '108th Street South',
#                '111th Street South',
#                '112th Street South',
#                '26th Street South',
#                '61st Street South',
#                '62nd Street South',
#                '63rd Street South',
#                '68th Street South',
#                '69th Street South',
#                '71st Street South',
#                '84th Street South',
#                '91st Street South',
#                '94th Street South',
#                '96th Street South',
#                '98th Street South',
#                'East 100th Street South',
#                'East 101st Street South',
#                'East 102nd Street South',
#                'East 103rd Street South',
#                'East 104th Street South',
#                'East 105th Street South',
#                'East 106th Street South',
#                'East 107th Street South',
#                'East 108th Street South',
#                'East 109th Street South',
#                'East 110th Street South',
#                'East 111th Street South',
#                'East 112th Place South',
#                'East 112th Street South',
#                'East 113th Street South',
#                'East 114th Street South',
#                'East 17th Street South',
#                'East 18th Street South',
#                'East 1st Street South',
#                'East 21st Street South',
#                'East 25th Street South',
#                'East 27th Street South',
#                'East 2nd Street South',
#                'East 32nd Street South',
#                'East 33rd Street South',
#                'East 34th Street South',
#                'East 35th Street South',
#                'East 36th Street South',
#                'East 37th Street South',
#                'East 38th Place South',
#                'East 38th Street South',
#                'East 39th Street South',
#                'East 3rd Street South',
#                'East 40th Street South',
#                'East 44th Street South',
#                'East 48th Street South',
#                'East 50th Street South',
#                'East 52nd Street South',
#                'East 59th Street South',
#                'East 5th Street South',
#                'East 60th Street South',
#                'East 61st Street South',
#                'East 62nd Street South',
#                'East 64th Street South',
#                'East 65th Street South',
#                'East 66th Street South',
#                'East 67th Street South',
#                'East 68th Street South',
#                'East 6th Street South',
#                'East 70th Street South',
#                'East 71st Street South',
#                'East 72nd Street South',
#                'East 73rd St South',
#                'East 74th St South',
#                'East 74th Street South',
#                'East 75th St South',
#                'East 76th Street South',
#                'East 79th Street South',
#                'East 81st Street South',
#                'East 82nd Street South',
#                'East 83rd Street South',
#                'East 84th Street South',
#                'East 86th Street South',
#                'East 87th Street South',
#                'East 89th Street South',
#                'East 91st Street South',
#                'East 92nd Street South',
#                'East 94th St South',
#                'East 94th Street South',
#                'East 95th Street South',
#                'East 96 St South',
#                'East 96th Street South',
#                'East 97th St South',
#                'East 97th Street South',
#                'East 98th Street South',
#                'East 99th Street South',
#                'South 67th Street South',
#                'West 104th Street South',
#                'West 105th Street South',
#                'West 106th Street South',
#                'West 107th Street South',
#                'West 108 Street South',
#                'West 108th Street South',
#                'West 109th Street South',
#                'West 110th Street South',
#                'West 111th Street South',
#                'West 112th Street South',
#                'West 113th Street South',
#                'West 21st Street South',
#                'West 26th Street South',
#                'West 27th Street South',
#                'West 31st Street South',
#                'West 35th Street South',
#                'West 41st Street South',
#                'West 42nd Street South',
#                'West 51st Street South',
#                'West 56th Street South',
#                'West 57th Street South',
#                'West 60th Street South',
#                'West 61st Street South',
#                'West 62nd Street South',
#                'West 63rd Street South',
#                'West 64th Street South',
#                'West 65th Street South',
#                'West 66th Street South',
#                'West 67th Street South',
#                'West 68th Street South',
#                'West 69th Street South',
#                'West 71st Street South',
#                'West 73rd Street South',
#                'West 74th Street South',
#                'West 76th Street South',
#                'West 78th Street South',
#                'West 79th Street South',
#                'West 80th Street South',
#                'West 81st Street South',
#                'West 82nd Street South',
#                'West 83rd Street South',
#                'West 84th Boulevard South',
#                'West 84th Street South',
#                'West 85th Street South',
#                'West 86th Street South',
#                'West 87th Street South',
#                'West 88th Street South',
#                'West 89th Street South',
#                'West 90th Street South',
#                'West 91st Street South',
#                'West 93rd Street South']),
#  'St': set(['S Quincy St']),
#  u'Store': set([u'99\xa2 & Up Discount Store']),
#  'Studio': set(['3CG Studio']),
#  'West': set(['South 40th Avenue West',
#               'South 49th Avenue West',
#               'South 51st Avenue West',
#               'South 73rd Avenue West']),
#  'independance': set(['independance']),
#  'sheridan': set(['sheridan']),
#  'street': set(['East 48th street'])}

# %%
#function to update street name
mapping = { "St": "Street",
            "St.": "Street",
            "Ave": "Avenue",
            "Rd.": "Road",
            "Rd": "Road",
            "Dr.": "Drive",
            "Avenu": "Avenue",
            "West Florence": "West Florence Street",
            'independence': "Independence Street",
            'sheridan': "Sheridan Street",
            'Main': 'Main Street'
            }
def update_name(name, mapping):
    for key,value in mapping.iteritems():
        if key in name:
            name = re.sub(key+"$", value, name)
    return name

#test the update street name function against Tulsa openstreetmap dataset
for st_type, ways in st_types.iteritems():
    for name in ways:
        better_name = update_name(name, mapping)
        print name, "=>", better_name
# Out:
# East Main => East Main Street
# S Cherokee => S Cherokee
# South Cherokee => South Cherokee
# South 73rd Avenue West => South 73rd Avenue West
# South 40th Avenue West => South 40th Avenue West
# South 51st Avenue West => South 51st Avenue West
# South 49th Avenue West => South 49th Avenue West
# Pebble Brook => Pebble Brook
# E BA Frontage Rd => E BA Frontage Road
# S. Sheridan Rd => S. Sheridan Road
# East 48th street => East 48th street
# North Old Highway 66 => North Old Highway 66
# South Memorial Dr. => South Memorial Drive
# North Hemlock Circle => North Hemlock Circle
# South 108th Avenue East => South 108th Avenue East
# South 71st Avenue East => South 71st Avenue East
# South Toledo Avenue East => South Toledo Avenue East
# South 106th Avenue East => South 106th Avenue East
# South 92nd Avenue East => South 92nd Avenue East
# South 94th Avenue East => South 94th Avenue East
# South 83rd Avenue East => South 83rd Avenue East
# South 101st Avenue East => South 101st Avenue East
# 288th Avenue East => 288th Avenue East
# South 118th Avenue East => South 118th Avenue East
# South 99th Avenue East => South 99th Avenue East
# South 167th Avenue East => South 167th Avenue East
# South 72nd Avenue East => South 72nd Avenue East
# South 74th Avenue East => South 74th Avenue East
# North 77th Avenue East => North 77th Avenue East
# South 173rd Avenue East => South 173rd Avenue East
# South 90th Avenue East => South 90th Avenue East
# North 10th Street East => North 10th Street East
# South 107th Avenue East => South 107th Avenue East
# South 87th Avenue East => South 87th Avenue East
# South 95th Avenue East => South 95th Avenue East
# South 91st Avenue East => South 91st Avenue East
# South 66th Avenue East => South 66th Avenue East
# South 139th Avenue East => South 139th Avenue East
# South 77th Avenue East => South 77th Avenue East
# South 261st Avenue East => South 261st Avenue East
# South 79th Avenue East => South 79th Avenue East
# South 70th Avenue East => South 70th Avenue East
# South 130th Avenue East => South 130th Avenue East
# South 67th Avenue East => South 67th Avenue East
# South 68th Avenue East => South 68th Avenue East
# South Sheridan Road East => South Sheridan Road East
# South 110th Avenue East => South 110th Avenue East
# West 82nd Street South => West 82nd Street South
# East 68th Street South => East 68th Street South
# West 42nd Street South => West 42nd Street South
# East 94th St South => East 94th St South
# East 73rd St South => East 73rd St South
# South 67th Street South => South 67th Street South
# East 32nd Street South => East 32nd Street South
# West 106th Street South => West 106th Street South
# West 56th Street South => West 56th Street South
# East 92nd Street South => East 92nd Street South
# East 96th Street South => East 96th Street South
# East 66th Street South => East 66th Street South
# East 62nd Street South => East 62nd Street South
# West 62nd Street South => West 62nd Street South
# 62nd Street South => 62nd Street South
# 26th Street South => 26th Street South
# Memorial Midtown Station Bay 11 => Memorial Midtown Station Bay 11
# Denver Avenue Station Bay 11 => Denver Avenue Station Bay 11
# 4616 W 84th St, Tulsa, OK  74132-3004 => 4616 W 84th St, Tulsa, OK  74132-3004
# sheridan => Sheridan Street
# Memorial Midtown Station Bay 12 => Memorial Midtown Station Bay 12
# Tulsa Fire Station Number 15 => Tulsa Fire Station Number 15
# 1045 => 1045
# Old Highway 51 => Old Highway 51
# 2502 => 2502
# South Olympia Avenu => South Olympia Avenue
# 49th Street Hill Church => 49th Street Hill Church
# S Peoria Ave => S Peoria Avenue
# S Harvard Ave => S Harvard Avenue
# West Florence => West Florence Street
# 3CG Studio => 3CG Studio

# %%
#function to check if postcode is a valid Tulsa postcode
def checkTulsazip(postcode):
    simplepostcode = postcode.split("-")[0]
    if len(simplepostcode) == 5 and int(simplepostcode[:2]) == 74:
        return True
    else:
        return False

# %%
import codecs
import json

#shaping and write data to json file

lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

CREATED = [ "version", "changeset", "timestamp", "user", "uid"]


def shape_element(element):
    node = {}
    created = {}
    address = {}
    if element.tag == "node" or element.tag == "way" :
        for key, value in element.attrib.iteritems():
            if key in CREATED:
                created[key] = value
            else:
                node[key] = value
        node["created"] = created
        node['type'] = element.tag
        if 'lat' and 'lon' in node:
            node['pos'] = [ float(node['lat']), float(node['lon']) ]
            #remove lat and lon keys in node since they are now in pos
            map(node.pop, ['lat','lon'])
        else:
            node['pos'] = None
        
        #get the k value for address
        for tag in element.iter('tag'):
            #ignore tag k with problem characters
            if re.search(problemchars, tag.attrib['k']):
                continue
            #add tag tag "k" value starts with "addr:" to a dictionary "address"
            elif re.search("addr:", tag.attrib['k']):
                #ignore the second ":" that separates the type/direction of a street
                if len(tag.attrib['k'].split(":")) < 3:
                    addresstag = tag.attrib['k'].split(":")[1]
                    address[addresstag] = tag.attrib['v']
            elif re.search("name:", tag.attrib['k']):
                if is_street_name(tag):
                    address["street"] = tag.attrib['v']
            else:
                address[tag.attrib['k']] = tag.attrib['v']
        #if there is an address, correct the street name and add address dictionery to the node dictionery
        if address:
            #update street name to get rid of typo, abbreviation
            if "street" in address:
                address["street"] = update_name(address["street"], mapping)
            #if postcode is not valid, delete it from address
            if "postcode" in address:
                if checkTulsazip(address['postcode']) == False:
                    address.pop('postcode')
            node['address'] = address
        
        
        
        #get the nd value
        nodereference = []
        for tag in element.iter('nd'):
            nodereference.append(tag.attrib['ref'])
        
        if nodereference:
            node['node_refs'] = nodereference
        return node
    else:
        return None


def process_map(file_in, pretty = False):
    file_out = "Cleaned {0}.json".format(file_in)
    with codecs.open(file_out, "w") as fo:
        for _, element in ET.iterparse(file_in):
            el = shape_element(element)
            if el:
                if pretty:
                    fo.write(json.dumps(el, indent=2)+"\n")
                else:
                    fo.write(json.dumps(el) + "\n")


process_map(rawOSMfile, False)
